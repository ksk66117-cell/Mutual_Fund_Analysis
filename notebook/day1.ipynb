# %%
import pandas as pd
import os

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User\Desktop\Mutual_Fund_Analytics 2

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'data', 'day1.ipynb', 'notebook']

# %%
import pandas as pd

df = pd.read_csv("data/01_fund_master.csv")
df.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
import os
os.listdir("data")
# Out:
# ['01_fund_master.csv',
#  '02_nav_history.csv',
#  '03_aum_by_fund_house.csv',
#  '04_monthly_sip_inflows.csv',
#  '05_category_inflows.csv',
#  '06_industry_folio_count.csv',
#  '07_scheme_performance.csv',
#  '08_investor_transactions.csv',
#  '09_portfolio_holdings.csv',
#  '10_benchmark_indices.csv',
#  'Anaconda3-2025.12-2-Windows-x86_64.exe',
#  'Bluestock_MF_Capstone_Project (1).pdf',
#  'Bluestock_MF_Capstone_Project.pdf',
#  'Git-2.54.0-64-bit.exe']

# %%
fund_master = pd.read_csv("data/01_fund_master.csv")
fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
nav = pd.read_csv("data/02_nav_history.csv")
nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
aum = pd.read_csv("data/03_aum_by_fund_house.csv")
aum.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
sip = pd.read_csv("data/04_monthly_sip_inflows.csv")
sip.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
cat = pd.read_csv("data/05_category_inflows.csv")
cat.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
folio = pd.read_csv("data/06_industry_folio_count.csv")
folio.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
perf = pd.read_csv("data/07_scheme_performance.csv")
perf.head()
# Out:
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# 2     119598    SBI Small Cap Fund - Regular Plan - Growth  SBI Mutual Fund
# 3     119599     SBI Small Cap Fund - Direct Plan - Growth  SBI Mutual Fund
# 4     119120  SBI Magnum Gilt Fund - Regular Plan - Growth  SBI Mutual Fund
#
#     category     plan  return_1yr_pct  return_3yr_pct  return_5yr_pct  \
# 0  Large Cap  Regular           12.42           12.36           14.45
# 1  Large Cap   Direct           15.25           11.30           14.23
# 2  Small Cap  Regular           24.56           23.39           20.67
# 3  Small Cap   Direct           20.59           23.14           21.82
# 4       Gilt  Regular            5.34            6.07            5.43
#
#    benchmark_3yr_pct  alpha  beta  sharpe_ratio  sortino_ratio  \
# ...

# %%
tx = pd.read_csv("data/08_investor_transactions.csv")
tx.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
holdings = pd.read_csv("data/09_portfolio_holdings.csv")
holdings.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
bench = pd.read_csv("data/10_benchmark_indices.csv")
bench.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
print("Fund Master:", fund_master.shape)
print("NAV:", nav.shape)
print("AUM:", aum.shape)
print("SIP:", sip.shape)
print("Category:", cat.shape)
print("Folio:", folio.shape)
print("Performance:", perf.shape)
print("Transactions:", tx.shape)
print("Holdings:", holdings.shape)
print("Benchmark:", bench.shape)
# Out:
# Fund Master: (40, 15)
# NAV: (46000, 3)
# AUM: (90, 5)
# SIP: (48, 6)
# Category: (144, 3)
# Folio: (21, 6)
# Performance: (40, 19)
# Transactions: (32778, 13)
# Holdings: (322, 8)
# Benchmark: (8050, 3)

# %%
import pandas as pd

files = [
"01_fund_master.csv",
"02_nav_history.csv",
"03_aum_by_fund_house.csv",
"04_monthly_sip_inflows.csv",
"05_category_inflows.csv",
"06_industry_folio_count.csv",
"07_scheme_performance.csv",
"08_investor_transactions.csv",
"09_portfolio_holdings.csv",
"10_benchmark_indices.csv"
]

data = {}

for f in files:
    df = pd.read_csv("data/" + f)
    data[f] = df
    print(f, "✔ Loaded ->", df.shape)
# Out:
# 01_fund_master.csv ✔ Loaded -> (40, 15)
# 02_nav_history.csv ✔ Loaded -> (46000, 3)
# 03_aum_by_fund_house.csv ✔ Loaded -> (90, 5)
# 04_monthly_sip_inflows.csv ✔ Loaded -> (48, 6)
# 05_category_inflows.csv ✔ Loaded -> (144, 3)
# 06_industry_folio_count.csv ✔ Loaded -> (21, 6)
# 07_scheme_performance.csv ✔ Loaded -> (40, 19)
# 08_investor_transactions.csv ✔ Loaded -> (32778, 13)
# 09_portfolio_holdings.csv ✔ Loaded -> (322, 8)
# 10_benchmark_indices.csv ✔ Loaded -> (8050, 3)

# %%
import requests
import pandas as pd

url = "https://api.mfapi.in/mf/125497"
res = requests.get(url)

json_data = res.json()

nav_live = pd.DataFrame(json_data["data"])
nav_live.head()
# Out:
#          date        nav
# 0  19-06-2026  202.07610
# 1  18-06-2026  200.95650
# 2  17-06-2026  199.83020
# 3  16-06-2026  198.61520
# 4  15-06-2026  198.03200

# %%
nav_live.to_csv("data/live_nav_125497.csv", index=False)

# %%
fund_master = pd.read_csv("data/01_fund_master.csv")

print("Fund Houses:", fund_master["fund_house"].nunique())
print("Categories:", fund_master["category"].nunique())
print("Risk Grades:", fund_master["risk_grade"].unique())
# Out:
# Fund Houses: 10
# Categories: 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'risk_grade'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 5
# ...

# %%
nav = pd.read_csv("data/02_nav_history.csv")

missing = set(fund_master["amfi_code"]) - set(nav["amfi_code"])

print("Missing AMFI codes in NAV:", missing)
# Out:
# Missing AMFI codes in NAV: set()

# %%
print("\n✅ DAY 1 STATUS REPORT")
print("1. All datasets loaded ✔")
print("2. Live NAV fetched ✔")
print("3. Data validation done ✔")
print("4. Project structure ready ✔")
print("\n🎯 DAY 1 COMPLETED SUCCESSFULLY")
# Out:
# ✅ DAY 1 STATUS REPORT
# 1. All datasets loaded ✔
# 2. Live NAV fetched ✔
# 3. Data validation done ✔
# 4. Project structure ready ✔
#
# 🎯 DAY 1 COMPLETED SUCCESSFULLY
